# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./Placement.csv")

# %%
data['hsc_b'].value_counts()
# Out:
# hsc_b
# Others     131
# Central     84
# Name: count, dtype: int64

# %%
df = pd.DataFrame(data.groupby(['hsc_b','status'])['status'].count())

# %%
df
# Out:
#                     status
# hsc_b   status
# Central Not Placed      27
#         Placed          57
# Others  Not Placed      40
#         Placed          91

# %%
sns.countplot(data=data,x='hsc_b',hue='status')
# Out:
# <Axes: xlabel='hsc_b', ylabel='count'>

# %%
sns.distplot(data['degree_p'],kde=True)
plt.title('Distribution of Degree Percentage')
plt.xlabel('Degree %')
# Out:
# C:\Users\deepr\AppData\Local\Temp\ipykernel_4452\1846070807.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['degree_p'],kde=True)
# Text(0.5, 0, 'Degree %')

# %%
df = pd.DataFrame(data.groupby(['workex','status'])['status'].count())

# %%
df
# Out:
#                    status
# workex status
# No     Not Placed      57
#        Placed          84
# Yes    Not Placed      10
#        Placed          64

# %%
data['workex'].value_counts()
# Out:
# workex
# No     141
# Yes     74
# Name: count, dtype: int64

# %%
sns.countplot(x='workex',hue='status',data = data)
# Out:
# <Axes: xlabel='workex', ylabel='count'>

# %%
sns.pairplot(data=data[['ssc_p','hsc_p','degree_p','etest_p','mba_p','salary','status']],hue='status',diag_kind='hist')

# %%
data.drop(['ssc_b','hsc_s','degree_t','salary'],axis=1,inplace=True)

# %%
data
# Out:
#      sl_no gender  ssc_p  hsc_p    hsc_b  degree_p workex  etest_p  \
# 0        1      M  67.00  91.00   Others     58.00     No     55.0
# 1        2      M  79.33  78.33   Others     77.48    Yes     86.5
# 2        3      M  65.00  68.00  Central     64.00     No     75.0
# 3        4      M  56.00  52.00  Central     52.00     No     66.0
# 4        5      M  85.80  73.60  Central     73.30     No     96.8
# ..     ...    ...    ...    ...      ...       ...    ...      ...
# 210    211      M  80.60  82.00   Others     77.60     No     91.0
# 211    212      M  58.00  60.00   Others     72.00     No     74.0
# 212    213      M  67.00  67.00   Others     73.00    Yes     59.0
# 213    214      F  74.00  66.00   Others     58.00     No     70.0
# 214    215      M  62.00  58.00   Others     53.00     No     89.0
#
#     specialisation  mba_p      status
# 0           Mkt&HR  58.80      Placed
# 1          Mkt&Fin  66.28      Placed
# 2          Mkt&Fin  57.80      Placed
# 3           Mkt&HR  59.43  Not Placed
# 4          Mkt&Fin  55.50      Placed
# ..             ...    ...         ...
# 210        Mkt&Fin  74.49      Placed
# 211        Mkt&Fin  53.62      Placed
# 212        Mkt&Fin  69.72      Placed
# 213         Mkt&HR  60.23      Placed
# 214         Mkt&HR  60.22  Not Placed
#
# [215 rows x 11 columns]

# %%
data["gender"] = data.gender.map({"M":0,"F":1})
data["workex"] = data.workex.map({"No":0,"Yes":1})
data["status"] = data.status.map({"Not Placed":0,"Placed":1})
data["specialisation"] = data.specialisation.map({"Mkt&HR":0,"Mkt&Fin":1})

# %%
data.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'hsc_p', 'hsc_b', 'degree_p', 'workex',
#        'etest_p', 'specialisation', 'mba_p', 'status'],
#       dtype='object')
